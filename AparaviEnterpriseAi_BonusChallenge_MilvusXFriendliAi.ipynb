# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pinecone-io/examples/blob/master/learn/generation/langchain/rag-chatbot.ipynb) [![Open nbviewer](https://raw.githubusercontent.com/pinecone-io/examples/master/assets/nbviewer-shield.svg)](https://nbviewer.org/github/pinecone-io/examples/blob/master/learn/generation/langchain/rag-chatbot.ipynb)

# %% [markdown]
# # APARAVI x MILVUS - Enterprise Challegne
# Welcome! You made it. We are excited to see what exciting project you will build with our software...
#
# This is the Enterprise UI challenge using the Milvus Vector Data Base Integration (https://milvus.io).
#
#  ### !A few things to consider!
#
# - Build something small and then extend! There is only little time...
# - Consider your hardware limitations. If you are limited in Memory and RAM, try a subset of our sample  data or just upload your own - its a hacknight your POC will be amazing no matter how large the data set - quality is what matters.
# - Think about no to vectorize everything. The point of the challenge is to indetify only the impornatn docs/
#
#
# ## Resources
#
# - Sample Data Set including HR, Finance, Legal and Health to build some powerul nterpise agents
# - Get the aparavi mac or mindwos os onstaler here:
# - Fview the quick installer quide here to get your platirmo running
# - you can also access more technical documentation here: https://aparavi-academy.eu/en/getting-started

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Once you have installed the platform you should see this screen - navigate to the sources tab.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Unchekc the "Inggerit from System Policy" Box and selcet "Add Source"
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Give your File System Source a meaningfull name and hit "Add Include Path"
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Enter the Path to you data and enable "Permissions", "Content Signatures", "Enable Indexing" and "Enable Classifications" and click "ok"
#
# ![image.png](attachment:image.png)

# %% [markdown]
# hit validate and submit
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Then hit "Save all Changes"
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Under the the Dashboard Tab "Status" you should see your scan job running, like this...
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Explore IT Tab

# %% [markdown]
# Make policies (add a note that this might take a while so people should be careful )
#
# To better understand our data and to later seperate it - lets add some classifications. Click on the administrations tab and choose "add Classification" and "Predefined Classification"
#
# ![image.png](attachment:image.png)
#
# For this example lets just focus on the finantional documents. Choose "General Finance and click ok. Don't forget to safe your changes. HNow you can go back to the Status tab from before and pbselfe how the olicy engnne runs
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Let's creat some tags to make best use of our data
#
# go to the "administrations" tab and press "create tag"
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Let's create a tag to mark our financial documents
#
# ![image.png](attachment:image.png)

# %% [markdown]
# let's use the "Discover Tab" to udnerstand our data a little beter
#
# ![image.png](attachment:image.png)
#
# we can build quries to browse through the data
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# The Query builder lets us select from a variety of sources
#
# ![image.png](attachment:image.png)

# %% [markdown]
# We want to filter our data for the financial documntation

# %%
# %pip install pymilvus

# %%
from pymilvus import connections, utility, MilvusException, MilvusClient, DataType, Collection

# %%
# make a connection to the milvus localhost
uri=f"http://localhost:19530"

# Establish a connection // TODO: Revise alternative setup 
connections.connect(
    uri=uri 
)  

# Init the store
client = MilvusClient(
    uri = uri,
    timeout= 60
)

# %% [markdown]
# list all currently present collections & info

# %%
# !pip freeze
# Out:
# anyio==4.4.0
# appdirs==1.4.4
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# asttokens==2.4.1
# attrs==23.2.0
# azure-core==1.30.1
# azure-storage-blob==12.20.0
# backoff==2.2.1
# boilerpy3==1.0.7
# cattrs==23.2.3
# certifi==2024.2.2
# cffi==1.16.0
# charset-normalizer==3.3.2
# colorama==0.4.6
# comm==0.2.2
# construct==2.5.3
# contourpy==1.2.1
# cryptography==42.0.7
# cycler==0.12.1
# debugpy==1.8.1
# decorator==5.1.1
# docopt==0.6.2
# environs==9.5.0
# Events==0.5
# executing==2.0.1
# farm-haystack==1.25.5
# filelock==3.14.0
# fonttools==4.53.0
# fsspec==2024.5.0
# grpcio==1.64.1
# grpcio-tools==1.64.1
# h11==0.14.0
# h2==4.1.0
# haystack==0.42
# hpack==4.0.0
# httpcore==1.0.5
# httpx==0.27.0
# huggingface-hub==0.23.2
# hyperframe==6.0.1
# idna==3.7
# inflect==7.2.1
# intel-openmp==2021.4.0
# ipykernel==6.29.4
# ipython==8.24.0
# isodate==0.6.1
# jedi==0.19.1
# Jinja2==3.1.4
# joblib==1.4.2
# jsonschema==4.22.0
# jsonschema-specifications==2023.12.1
# jupyter_client==8.6.2
# jupyter_core==5.7.2
# kaleido==0.2.1
# kiwisolver==1.4.5
# lazy-imports==0.3.1
# MarkupSafe==2.1.5
# marshmallow==3.21.2
# matplotlib==3.9.0
# matplotlib-inline==0.1.7
# minio==7.2.7
# mkl==2021.4.0
# monotonic==1.6
# more-itertools==10.2.0
# mpmath==1.3.0
# nest-asyncio==1.6.0
# networkx==3.3
# num2words==0.5.13
# numpy==1.26.4
# packaging==24.0
# pandas==2.2.2
# parso==0.8.4
# patsy==0.5.6
# pefile==2023.2.7
# pillow==10.3.0
# platformdirs==4.2.2
# portalocker==2.10.0
# posthog==3.5.0
# prompt-toolkit==3.0.43
# prompthub-py==4.0.0
# protobuf==5.27.1
# psutil==5.9.8
# pure-eval==0.2.2
# pyarrow==16.1.0
# pyasn1==0.6.0
# pycparser==2.22
# pycryptodome==3.20.0
# pydantic==1.10.15
# Pygments==2.18.0
# pymilvus==2.4.1
# pyparsing==3.1.2
# python-dateutil==2.9.0.post0
# python-dotenv==1.0.1
# python-ptrace==0.9.9
# pytz==2024.1
# pywin32==306
# PyYAML==6.0.1
# pyzmq==26.0.3
# qdrant-client==1.9.2
# quantulum3==0.9.1
# rank-bm25==0.2.2
# referencing==0.35.1
# regex==2024.5.15
# requests==2.32.3
# requests-cache==0.9.8
# rpds-py==0.18.1
# safetensors==0.4.3
# scikit-learn==1.5.0
# scipy==1.13.1
# seaborn==0.13.2
# sentence-transformers==3.0.0
# setuptools==70.0.0
# six==1.16.0
# sniffio==1.3.1
# sqlparse==0.5.0
# sseclient-py==1.8.0
# stack-data==0.6.3
# statsmodels==0.14.2
# sympy==1.12.1
# tabulate==0.9.0
# tbb==2021.12.0
# tenacity==8.3.0
# threadpoolctl==3.5.0
# tiktoken==0.7.0
# tokenizers==0.15.2
# torch==2.3.0
# tornado==6.4
# tqdm==4.66.4
# traitlets==5.14.3
# transformers==4.39.3
# typeguard==4.3.0
# typing==3.7.4.3
# typing_extensions==4.12.0
# tzdata==2024.1
# ujson==5.10.0
# url-normalize==1.4.3
# urllib3==2.2.1
# wcwidth==0.2.13
# Werkzeug==3.0.3
# wsproto==1.2.0

# %%
client.list_collections()
# Out:
# ['WebsiteTest', 'test', 'try', 'Student', 'Faculty']

# %%
client.describe_collection('APARAVI')
# Out:
# {'collection_name': 'APARAVI',
#  'auto_id': False,
#  'num_shards': 1,
#  'description': '',
#  'fields': [{'field_id': 100,
#    'name': 'id',
#    'description': '',
#    'type': <DataType.INT64: 5>,
#    'params': {},
#    'is_primary': True},
#   {'field_id': 101,
#    'name': 'vector',
#    'description': '',
#    'type': <DataType.FLOAT_VECTOR: 101>,
#    'params': {'dim': 384}},
#   {'field_id': 102,
#    'name': 'content',
#    'description': '',
#    'type': <DataType.VARCHAR: 21>,
#    'params': {'max_length': 65535}},
#   {'field_id': 103,
#    'name': 'objectId',
#    'description': '',
#    'type': <DataType.VARCHAR: 21>,
#    'params': {'max_length': 300}},
#   {'field_id': 104,
#    'name': 'nodeId',
#    'description': '',
#    'type': <DataType.VARCHAR: 21>,
#    'params': {'max_length': 300}},
#   {'field_id': 105,
#    'name': 'parent',
#    'description': '',
#    'type': <DataType.VARCHAR: 21>,
#    'params': {'max_length': 300}},
#   {'field_id': 106,
#    'name': 'permissionId',
#    'description': '',
#    'type': <DataType.INT64: 5>,
#    'params': {}},
#   {'field_id': 107,
#    'name': 'isDeleted',
#    'description': '',
#    'type': <DataType.BOOL: 1>,
#    'params': {}},
#   {'field_id': 108,
#    'name': 'chunk',
#    'description': '',
#    'type': <DataType.INT64: 5>,
#    'params': {}}],
#  'aliases': [],
#  'collection_id': 450721443574929882,
#  'consistency_level': 2,
#  'properties': {},
#  'num_partitions': 1,
#  'enable_dynamic_field': False}

# %% [markdown]
# # TEST THE RENDER CHUNKS METHOD

# %%
# settings filter 
objectId = "obj-2"
collection_name = 'APARAVI'

must_condition = []

# more parameters
i=0
renderChunkSize = 1000
# Since chunks are returned in any order, and a single objectId
# may contain tens of thousands of chunks, we grave them one
# group at a time (renderChunkSize), put them into an array,
# join them and call the callback
offset = 0

# %%
# do the rendering
while (True):

    # Build filter for getting a set of chunks within the offset range
    must_condition = f"objectId == '{objectId}' && chunk >= {offset} && chunk < {offset + renderChunkSize}"

    results = client.query(
        collection_name = collection_name,
        filter = must_condition
    )
    
    # Create a renderChunkSize array with empty
    # entries. This will allow us to join even when
    # a chunk doesn't come back
    # Process the results
    text = [''] * renderChunkSize
    lastIndex = -1

    for point in results:
        content = point['content']
        chunk = point['chunk']
        index = chunk - offset

        # Should never happen since we gave it an offset
        if chunk < offset:
            continue

        text[index] = content
        if index > lastIndex:
            lastIndex = index

    # Compute the number of items we are going to process
    numberOfItems = lastIndex + 1

    # If we got no items back, we are done
    if numberOfItems < 1:
        break

    # Join it together
    fullText = ''.join(text[0:numberOfItems])

    # Call the output function
    print('number',i,'text:',fullText)

    i = i+1 
    # If we got less than we asked for, must be done
    if (numberOfItems < renderChunkSize):
        break
    
    offset += renderChunkSize

# %%
print(fullText)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(fullText)
#
# NameError: name 'fullText' is not defined

# %% [markdown]
# # TEST THE SEARCH FUNCTION

# %%
# !python -c "import numpy; print(numpy.__version__)"
# Out:
# 1.26.4

# %%
similarity = 'COSINE'
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('sentence-transformers/multi-qa-MiniLM-L6-cos-v1')
collection = 'Student'
# Out:
# c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
query = "Wer ist Rauber Hotzenklotz?"



# Get the vectors
queryVectors = model.encode(query, show_progress_bar = False)

# %%
semantic=True
nodeId =None
parent = None
permissionId =  [-1]
isDeleted=False
offset=0
limit=10

# %%
from typing import List
from haystack.schema import Document

# Check it
if client == None:
    raise Exception('Client is not started')

# Declare the results list
results: List[Document] = []

# Declare the must list to start adding conditions
must_conditions = []
output_fields   = ['nodeId','parent','permissionId','isDeleted','chunk','content']

# If a parent was specified
if nodeId:
    must_conditions.append(f"nodeId == '{nodeId}'"),
    
# If a parent was specified
if parent:
    must_conditions.append(f"parent == '{parent}'")
    

# If a permissionId list was specified
if permissionId:
    permission_ids = ', '.join(map(str, permissionId))
    must_conditions.append(f"permissionId in [{permission_ids}]")
    

# If we are not going after deleted docs, add a condition
if not isDeleted:
    must_conditions.append("isDeleted == False")

# If we are doing a semantic search or not...
if semantic:
    # Optionally embed the query
    if query != None:
        embedding = model.encode(query)
else:
    # Check it
    if query == None:
        raise Exception('You must specify the keyword in the query')
    
    # Append it
    must_conditions.append(f"content like '%{query}%'")

# Combine all conditions into a single filter expression
filter_expression = ' and '.join(must_conditions) if must_conditions else None


if semantic:
    # Check it
    if embedding is None:
        raise Exception('Embedding not specified in search')
    
    # Perform the search
    points = client.search(
        collection_name=collection,
        data = embedding.reshape(1, -1),
        filter=filter_expression,
        limit=limit,
        output_fields=output_fields							
    )

    # Build the document list
    for scored in points[0]:
         #for scored in scoredList:
           #for scores in scored:# print(scored) 
                # Check it
                if not isinstance(scored, dict):
                    raise Exception('scored search is not a dictionary')

                if not isinstance(scored.get('id'), int):
                    raise Exception('scored id is not an integer')

                # Get the payload
                entity = scored.get('entity')
                if entity is None:
                    raise Exception('scored payload is not present')

                # Process the entity as needed
                content  = entity.get('content')
                meta = {
                    'parent': entity.get('parent'),
                    'chunk': entity.get('chunk'),
                    'objectId': entity.get('objectId'),
                    'nodeId': entity.get('nodeId')
                }

                doc = Document(
                    id=scored['id'],
                    content=content,
                    meta=meta # is that already all the meta data we need? id?
                )

                # If we are return scaled scores, build it TODO: CHECK IF THIS IS ALSO THE CASE FOR MILVUS (-1 to 1 range)
                if similarity == "COSINE":
                    doc.score = (scored.get('distance') + 1) / 2
                else:
                    doc.score = float(expit(scored.get('distance') / 100))

                # Ignore it if it doesn't have a high enough score
                if (doc.score < .20):
                    continue

                # Append it to the results
                results.append(doc)
else:

    # Perform the keyword solo  search
    points = client.query(
        collection_name=collection,
        filter=filter_expression,
        output_fields=output_fields,
    ) 
    

    # Now, add the documents to the results
    for point in points:
        print(point)
        # Ensure the point has the required fields
        if 'id' not in point or 'content' not in point or 'parent' not in point or 'chunk' not in point or 'objectId' not in point or 'nodeId' not in point:
            continue

        # Build the document
        doc = Document(
            id=point['id'],  # Assuming 'id' is now an integer
            content=point['content'],
            meta={
                'parent': point['parent'],
                'chunk': point['chunk'],
                'objectId': point['objectId'],
                'nodeId': point['nodeId']
            }
        )

        # Append it to the results
        results.append(doc)
# Out:
# ---------------------------------------------------------------------------
# PydanticSchemaGenerationError             Traceback (most recent call last)
# Cell In[7], line 2
#       1 from typing import List
# ----> 2 from haystack.schema import Document
#       4 # Check it
#       5 if client == None:
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\haystack\__init__.py:10
#       6 __version__: str = str(metadata.version("farm-haystack"))
#       9 import haystack.silenceable_tqdm  # Needs to be imported first to wrap TQDM for all following modules
# ---> 10 from haystack.schema import Document, Answer, Label, MultiLabel, Span, EvaluationResult, TableCell
#      11 from haystack.nodes.base import BaseComponent
#      12 from haystack.pipelines.base import Pipeline
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\haystack\schema.py:41
#      36 FilterType = Dict[str, Union[Dict[str, Any], List[Any], str, int, float, bool]]
#      38 LABEL_DATETIME_FORMAT: str = "%Y-%m-%d %H:%M:%S"
# ---> 41 @dataclass
#      42 class Document:
#      43     id: str
#      44     content: Union[str, DataFrame]
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\dataclasses.py:264, in dataclass(_cls, init, repr, eq, order, unsafe_hash, frozen, config, validate_on_init, kw_only, slots)
#     261     _pydantic_dataclasses.complete_dataclass(cls, config_wrapper, raise_errors=False, types_namespace=None)
#     262     return cls
# --> 264 return create_dataclass if _cls is None else create_dataclass(_cls)
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\dataclasses.py:261, in dataclass.<locals>.create_dataclass(cls)
#     259 cls.__qualname__ = original_cls.__qualname__
#     260 cls.__pydantic_complete__ = False  # `complete_dataclass` will set it to `True` if successful.
# --> 261 _pydantic_dataclasses.complete_dataclass(cls, config_wrapper, raise_errors=False, types_namespace=None)
#     262 return cls
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_dataclasses.py:160, in complete_dataclass(cls, config_wrapper, raise_errors, types_namespace)
#     151         schema = get_core_schema(
#     152             cls,
#     153             CallbackGetCoreSchemaHandler(
#    (...)
#     157             ),
#     158         )
#     159     else:
# --> 160         schema = gen_schema.generate_schema(cls, from_dunder_get_core_schema=False)
#     161 except PydanticUndefinedAnnotation as e:
#     162     if raise_errors:
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_generate_schema.py:655, in GenerateSchema.generate_schema(self, obj, from_dunder_get_core_schema)
#     652         schema = from_property
#     654 if schema is None:
# --> 655     schema = self._generate_schema_inner(obj)
#     657 metadata_js_function = _extract_get_pydantic_json_schema(obj, schema)
#     658 if metadata_js_function is not None:
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_generate_schema.py:929, in GenerateSchema._generate_schema_inner(self, obj)
#     926 if isinstance(obj, PydanticRecursiveRef):
#     927     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
# --> 929 return self.match_type(obj)
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_generate_schema.py:1025, in GenerateSchema.match_type(self, obj)
#    1022     return self._zoneinfo_schema()
#    1024 if _typing_extra.is_dataclass(obj):
# -> 1025     return self._dataclass_schema(obj, None)
#    1027 origin = get_origin(obj)
#    1028 if origin is not None:
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_generate_schema.py:1822, in GenerateSchema._dataclass_schema(self, dataclass, origin)
#    1819 decorators = dataclass.__dict__.get('__pydantic_decorators__') or DecoratorInfos.build(dataclass)
#    1820 # Move kw_only=False args to the start of the list, as this is how vanilla dataclasses work.
#    1821 # Note that when kw_only is missing or None, it is treated as equivalent to kw_only=True
# -> 1822 args = sorted(
#    1823     (self._generate_dc_field_schema(k, v, decorators) for k, v in fields.items()),
#    1824     key=lambda a: a.get('kw_only') is not False,
#    1825 )
#    1826 has_post_init = hasattr(dataclass, '__post_init__')
#    1827 has_slots = hasattr(dataclass, '__slots__')
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_generate_schema.py:1823, in <genexpr>(.0)
#    1819 decorators = dataclass.__dict__.get('__pydantic_decorators__') or DecoratorInfos.build(dataclass)
#    1820 # Move kw_only=False args to the start of the list, as this is how vanilla dataclasses work.
#    1821 # Note that when kw_only is missing or None, it is treated as equivalent to kw_only=True
#    1822 args = sorted(
# -> 1823     (self._generate_dc_field_schema(k, v, decorators) for k, v in fields.items()),
#    1824     key=lambda a: a.get('kw_only') is not False,
#    1825 )
#    1826 has_post_init = hasattr(dataclass, '__post_init__')
#    1827 has_slots = hasattr(dataclass, '__slots__')
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_generate_schema.py:1132, in GenerateSchema._generate_dc_field_schema(self, name, field_info, decorators)
#    1125 def _generate_dc_field_schema(
#    1126     self,
#    1127     name: str,
#    1128     field_info: FieldInfo,
#    1129     decorators: DecoratorInfos,
#    1130 ) -> core_schema.DataclassField:
#    1131     """Prepare a DataclassField to represent the parameter/field, of a dataclass."""
# -> 1132     common_field = self._common_field_schema(name, field_info, decorators)
#    1133     return core_schema.dataclass_field(
#    1134         name,
#    1135         common_field['schema'],
#    (...)
#    1143         metadata=common_field['metadata'],
#    1144     )
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_generate_schema.py:1308, in GenerateSchema._common_field_schema(self, name, field_info, decorators)
#    1304         schema = self._apply_annotations(
#    1305             source_type, annotations + validators_from_decorators, transform_inner_schema=set_discriminator
#    1306         )
#    1307     else:
# -> 1308         schema = self._apply_annotations(
#    1309             source_type,
#    1310             annotations + validators_from_decorators,
#    1311         )
#    1313 # This V1 compatibility shim should eventually be removed
#    1314 # push down any `each_item=True` validators
#    1315 # note that this won't work for any Annotated types that get wrapped by a function validator
#    1316 # but that's okay because that didn't exist in V1
#    1317 this_field_validators = filter_field_decorator_info_by_field(decorators.validators.values(), name)
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_generate_schema.py:2107, in GenerateSchema._apply_annotations(self, source_type, annotations, transform_inner_schema)
#    2102         continue
#    2103     get_inner_schema = self._get_wrapped_inner_schema(
#    2104         get_inner_schema, annotation, pydantic_js_annotation_functions
#    2105     )
# -> 2107 schema = get_inner_schema(source_type)
#    2108 if pydantic_js_annotation_functions:
#    2109     metadata = CoreMetadataHandler(schema).metadata
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_schema_generation_shared.py:83, in CallbackGetCoreSchemaHandler.__call__(self, source_type)
#      82 def __call__(self, source_type: Any, /) -> core_schema.CoreSchema:
# ---> 83     schema = self._handler(source_type)
#      84     ref = schema.get('ref')
#      85     if self._ref_mode == 'to-def':
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_generate_schema.py:2088, in GenerateSchema._apply_annotations.<locals>.inner_handler(obj)
#    2086 from_property = self._generate_schema_from_property(obj, source_type)
#    2087 if from_property is None:
# -> 2088     schema = self._generate_schema_inner(obj)
#    2089 else:
#    2090     schema = from_property
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_generate_schema.py:929, in GenerateSchema._generate_schema_inner(self, obj)
#     926 if isinstance(obj, PydanticRecursiveRef):
#     927     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
# --> 929 return self.match_type(obj)
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_generate_schema.py:1029, in GenerateSchema.match_type(self, obj)
#    1027 origin = get_origin(obj)
#    1028 if origin is not None:
# -> 1029     return self._match_generic_type(obj, origin)
#    1031 res = self._get_prepare_pydantic_annotations_for_known_type(obj, ())
#    1032 if res is not None:
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_generate_schema.py:1058, in GenerateSchema._match_generic_type(self, obj, origin)
#    1055     return from_property
#    1057 if _typing_extra.origin_is_union(origin):
# -> 1058     return self._union_schema(obj)
#    1059 elif origin in TUPLE_TYPES:
#    1060     return self._tuple_schema(obj)
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_generate_schema.py:1378, in GenerateSchema._union_schema(self, union_type)
#    1376         nullable = True
#    1377     else:
# -> 1378         choices.append(self.generate_schema(arg))
#    1380 if len(choices) == 1:
#    1381     s = choices[0]
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_generate_schema.py:655, in GenerateSchema.generate_schema(self, obj, from_dunder_get_core_schema)
#     652         schema = from_property
#     654 if schema is None:
# --> 655     schema = self._generate_schema_inner(obj)
#     657 metadata_js_function = _extract_get_pydantic_json_schema(obj, schema)
#     658 if metadata_js_function is not None:
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_generate_schema.py:929, in GenerateSchema._generate_schema_inner(self, obj)
#     926 if isinstance(obj, PydanticRecursiveRef):
#     927     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
# --> 929 return self.match_type(obj)
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_generate_schema.py:1038, in GenerateSchema.match_type(self, obj)
#    1036 if self._arbitrary_types:
#    1037     return self._arbitrary_type_schema(obj)
# -> 1038 return self._unknown_type_schema(obj)
#
# File c:\Users\HendrikKrack\AppData\Local\Programs\Python\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\pydantic\_internal\_generate_schema.py:558, in GenerateSchema._unknown_type_schema(self, obj)
#     557 def _unknown_type_schema(self, obj: Any) -> CoreSchema:
# --> 558     raise PydanticSchemaGenerationError(
#     559         f'Unable to generate pydantic-core schema for {obj!r}. '
#     560         'Set `arbitrary_types_allowed=True` in the model_config to ignore this error'
#     561         ' or implement `__get_pydantic_core_schema__` on your type to fully support it.'
#     562         '\n\nIf you got this error by calling handler(<some type>) within'
#     563         ' `__get_pydantic_core_schema__` then you likely need to call'
#     564         ' `handler.generate_schema(<some type>)` since we do not call'
#     565         ' `__get_pydantic_core_schema__` on `<some type>` otherwise to avoid infinite recursion.'
#     566     )
#
# PydanticSchemaGenerationError: Unable to generate pydantic-core schema for <class 'pandas.core.frame.DataFrame'>. Set `arbitrary_types_allowed=True` in the model_config to ignore this error or implement `__get_pydantic_core_schema__` on your type to fully support it.
#
# If you got this error by calling handler(<some type>) within `__get_pydantic_core_schema__` then you likely need to call `handler.generate_schema(<some type>)` since we do not call `__get_pydantic_core_schema__` on `<some type>` otherwise to avoid infinite recursion.
#
# For further information visit https://errors.pydantic.dev/2.9/u/schema-for-unknown-type

# %%
# print score
print(results)
print(scored)
# Out:
# [<Document: {'content': '\nClient #2 (Institutional) https://hedgefollow.com/funds/Renaissance+Technologies\nRENAISSANCE\nJim Simons | RENAISSANCE TECHNOLOGIES | Quant -shop\nFocus on growth\n$92B quant shop\nRENAISSANCE\nTECHNOLOGIES’ focus seems\nto be on “hot” growth stocks.\nSome of the holdings are in\npost IPO stocks that just had\ntheir floor debut.\nGeographic\ndiversification\nCompared to other domestic\nhedge funds - Jim Simons like\nto invest in growth stocks that\nhave their main operations\nbased abroad. Jim believes\nthat there is more growth in\nother countries than in the US -\nso that’s why he selects\ncompanies from different geo\nlocations.\nTeaching others.\nJim Simons is a world famous\nmathematician who founded\nRENAISSANCE\nTECHNOLOGIES. He taught\nmathematics at MIT and\nHarvard.\nhttps://hedgefollow.com/funds/Renaissance+Technologies Caption\nFocus on growth $92B quant shop\nGeographic diversification\nTeaching others.', 'content_type': 'text', 'score': 0.5254990719258785, 'meta': {'parent': 'C:/Users/HendrikKrack/Desktop/Test_textoutput/text_output/C$/Users/HendrikKrack/WorkBench/TextOutputConnector_Debug/aparavi-connectors/testdata/source2/Profile 2 - Renaissance.pdf', 'chunk': 0, 'objectId': None, 'nodeId': '35e3fa3f-apag-4871-b5f7-609a167a06a1'}, 'id_hash_keys': ['content'], 'embedding': None, 'id': '590068919650319345'}>, <Document: {'content': '\nClient #1 (Institutional) https://hedgefollow.com/funds/Berkshire+Hathaway\nBERKSHIRE H.\nWarren Buffet | Berkshire Hathaway | “Hedge Fund”\nFocus on US $270B\nBerkshire Hathaway has always\nbeen invested in US-domestic\nequity positions. There are very\ninsignificant amounts (if non-\nexisting) of fixed income\nassets.\nChanging sector\nfocus\nThe president of B.H., Warren\nBuffet, has always been\ninterested in different sectors.\nUntil recently, the fund had a Biggest holdings:\nhuge allocation in the financial\nindustries, but has been\nrebalancing the portfolio to AAPL (Apple Inc): 44%\ninclude more technology\ncompanies, such as Apple, BAC (Bank of Amer):\nSnowflake , and Verizon +T-\nMobile 11%KO (Coca Cola) : 8%\nTeaching others.\nWarren Buffet’s name is AXP (Amer. Express): 7%\nlegendary in the financial\nindustry. Every trade is being\nclosely watched by VZ (Verizon): 3%\nprofessionals and impacts the\nentire market - since the trade SNOW (Snowflake Inc): 1%\nvolumes are high.\nhttps://hedgefollow.com/funds/Berkshire+Hathaway\nFocus on US $270B\nChanging sector focus\nTeaching others.\nBiggest holdings:', 'content_type': 'text', 'score': 0.49812081828713417, 'meta': {'parent': 'C:/Users/HendrikKrack/Desktop/Test_textoutput/text_output/C$/Users/HendrikKrack/WorkBench/TextOutputConnector_Debug/aparavi-connectors/testdata/source2/Profile 1 - Berkshire.pdf', 'chunk': 0, 'objectId': None, 'nodeId': '35e3fa3f-apag-4871-b5f7-609a167a06a1'}, 'id_hash_keys': ['content'], 'embedding': None, 'id': '589783619749902603'}>, <Document: {'content': '\nClient #3 (Institutional) https://hedgefollow.com/funds/Bridgewater+Associates\nBRIDGEWATER\nRay Dalio | BRIDGEWATER | Indexes\nPassive - index\nfocused 11B\nBRIDGEWATER is a passive\nfund that is focused on asset\nallocation in different equity\nindexes (it’s 2 biggest holdings\nare SPY and VWO)\nGeographic\ndiversification\nThis fund tries to find the right\ncombination of domestic and\ninternational investments.\nDepending on the short term\noutlook - the fund might have\na higher allocation to domestic\nequities. On the other hand,\nwhen emerging markets\ndeliver higher returns - in\ntimes of economic expansion -\nthe fund shifts to indexes\ninvested in those countries.\nTeaching others.\nPAIN + REFLECTION =\nPROGRESS Ray Dalio\npublished multiple books -\nincluding the best selling,\n“PRINCIPLES”\nhttps://www.principles.com/\nhttps://hedgefollow.com/funds/Bridgewater+Associates Caption\nPassive - index focused 11B\nGeographic diversification\nTeaching others.', 'content_type': 'text', 'score': 0.486186135560 ...
# {'id': 590589908055180709, 'distance': -0.1499892771244049, 'entity': {'nodeId': '35e3fa3f-apag-4871-b5f7-609a167a06a1', 'parent': 'C:/Users/HendrikKrack/Desktop/Test_textoutput/text_output/C$/Users/HendrikKrack/WorkBench/TextOutputConnector_Debug/aparavi-connectors/testdata/source2/Profile 4 - Fisher.pdf', 'permissionId': -1, 'isDeleted': False, 'chunk': 0, 'content': '\nClient #4 (Institutional) https://hedgefollow.com/funds/Fisher+Asset+Management\nFISHER\nKen Fisher | FISHER INVESTMENTS | Family Office\nFocus on technology\n$133B\nFisher Investments is a fund\nbased in Palo Alto, CA, serving\nsilicon valley wealthy\ncustomers from around the\nBay Area.\nChanging to\ntechnology focus\nThe fund has recently\noutperformed thanks to its\ntechnology overweighted\nstrategy. The fund bought\nboth, domestic and\ninternational technology stocks\nand is betting on a fast\nrecovery in asian growth\nstocks.\nTeaching others.\nKen Fisher is a silicon valley\nguru, who provides advice and\nconsults ultra high net worth\ninvestors from the Bay Area.\nHe’s a financial columnist,\nhaving published in\npublications around the globe,\nin Europe and Asia.\nhttps://www.kenfisher.com/\nhttps://hedgefollow.com/funds/Fisher+Asset+Management\nFocus on technology $133B\nChanging to technology focus\nTeaching others.'}}

# %% [markdown]
# # Test the flush function to seal the collection

# %%
from pymilvus import connections, Collection
# make a connection 
uri=f"http://localhost:19530"

# Establish a connection // TODO: Revise alternative setup 
connections.connect(
    uri=uri 
)
collectionInst = Collection(name="APARAVI_TEST")

collectionInst.flush()

client.get_collection_stats("APARAVI")

# %% [markdown]
# Do simple key word search

# %%
#parent = 'C:/Users/HendrikKrack/WorkBench/TextOutputConnector_Debug/aparavi-connectors/testdata/source/brunner22uwbwifi.pdf'
#filter_expression = f"parent == '{parent}'"
output_fields   = ['objectId','nodeId','parent','permissionId','isDeleted','chunk','content']

# %%
collection = 'Student'

# Perform the keyword solo  search
points = client.query(
    collection_name=collection,
    #filter=filter_expression,
    output_fields=output_fields,
    limit = 10
)

# %%
print(points)
# Out:
# [{'isDeleted': False, 'chunk': 0, 'content': '\nAdd Authenticator App to Account with My Sign-Ins : Hult International Business School https://ef-hult.freshservice.com/support/solutions/articles/50000138943-add-authenticator-app-to-account-with-my-sign-ins\nAdd Authenticator App to Account with My Sign-Ins\nModified on: Mon, 6 Mar, 2023 3:25 PM\n1 of 4 9/14/2024, 5:33 PM\nAdd Authenticator App to Account with My Sign-Ins : Hult International Business School https://ef-hult.freshservice.com/support/solutions/articles/50000138943-add-authenticator-app-to-account-with-my-sign-ins\n2 of 4 9/14/2024, 5:33 PM\nAdd Authenticator App to Account with My Sign-Ins : Hult International Business School https://ef-hult.freshservice.com/support/solutions/articles/50000138943-add-authenticator-app-to-account-with-my-sign-ins\n3 of 4 9/14/2024, 5:33 PM\nAdd an Authenticator to Account with My Sign-Ins (https://app.tango.us/app/workflow/Add-an-Authenticator-to-Account-0aff71327775458cabdfbb3592ff412d)\n1 Attachment\nCan\'t find what you\'re looking for?\nSubmit a ticket\nif you need help with your computer, email, etc.\nHow can we help you today?\nSTEP\nGo to My Sign-Ins Microsoft.com\nSTEP\nClick on Security Info\nEF Sign-Ins\nRecent activity\nOvcaasv\nSecunty info You %hould recognize csch {hese\'ccca? Icuivilies If @nelooksunfa\nOrgsnuJ:on: Today at 9 5724AМ EST Masaehu\nDexices Locsgon Opcrating Sy:tcm Eros\nMassachuzetts US Windo: š 10 5809\nancnesle\nPrevacy\n1ergo\nSTEP\nClick on Add sign-in met\nEF My Sỉgn-Ins\nOvemviev Security info\nThese øre the methodsyou use \'sign into your account IGso\nSccurỉly info\nDcfault :ỉgn-ỉn mcthod: Microsoft Authenticator notnication\nOrganizations\nAdd sign-in method\n(xsees Hpds 8i6 Tenzo\nSTEP\nClick on Choose method\nAdd a method\nWhich method would you like to add?\nChoose method\nCancel Ada\nMedc #llh Tangous\nSTEP\nSelect Authenticator APP and then Add\nAdd a method\nWhich method vould you like to add?\nAuthenticator app\nCancel Add\nMego aih Fongo Ms\n\'STEP\nOn your Smartphone:\nGo to the apple store or Google store and download the app called; Microsoft\nAuthenticator "\nOpen App and Click on and add Work or School Account.\nEnter your Hult student email (e.& KRichards@student hultedu)\nYou wỉll be prompted scan@RScantheQRCo.de on the screen- Go the next\nstep\nSTEP\nBack on your laptop Click on Next\nMicrosoft Authenticator\nStart by getting the app\nOnyou Phoae "rs83bi Microcott Authen:kator SPp Dowrloeanow\nAter sou insto fhe Microzoft Authen:cator PP @nvov; @evice chooie \'Next\nNang Usc difforcn: authcaticator JDD\nCanccl Nert\n18880 vilh 32060M6\n\'STEP\nClick on Next\nMicrosoft Authenticator\nSet up your account\nIf promptod Jllow DO:IiCatvonr Ihsnsdd,0ExcOuo: Jnd coloct "Wlork & \'chool\'\nGark on\n4ba ~r 1040\n\'STEP\nScan the QR Code with your smartphone\nMicrosoft Authcnticator\nScan the QR coe\nPa oYcii B83[ne 08ex 2 RV"yat0#\n)ou: @ ounf\nECsaipo 8983 Ye\'8\nlaeeBf\nAi (62" "\nSTEP 10\nThe Authenticator ask for verification. ', 'id': 716969220969463346, 'objectId': '04952d49-iobj-431a-b8e0-bae4e93c014b', 'nodeId': '8646a1b1-apag-48eb-a9a7-0384a21db009', 'parent': 'C:/Users/HendrikKrack/Desktop/Aparavi_HultChatbo/KnowledgeBase/StudentArticles/Addauthenticatorapp.pdf', 'permissionId': -1}, {'isDeleted': False, 'chunk': 0, 'content': "\nAdd/Manage Email Addresses in myCourses\nModified on: Tue, 3 Mar, 2020 6:47 AM\nYou can add emails to your profile in myCourses, for example if you wish to get notifications to a different email address.\nGo to settings (https://hult.instructure.com/profile/settings) and on the right hand side you'll see your currently registered emails (the starred one is your primary).\nCan't find what you're looking for?\nSubmit a ticket\nif you need help with your computer, email, etc.\nHow can we help you today?\nWays to Contact\nEmail Addresses\nsoren.riber@hultedu\nsoren.riber@ef.com\nEmail Address\nhttps://ef-hultfreshservice.com/support/\nAddIManage Email Add ...
